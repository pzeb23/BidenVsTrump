# %%
import pandas as pd
import emoji
import nltk

# %%
import pickle as pkl
import json
import re

# %%
filename = "/Users/imac/Documents/Tweets data/Trump_tweets.pkl"
filename2 = "/Users/alexkowalski/Documents/Biden_tweets.pkl"

# %%
with open(filename2, 'rb') as f:
    data = pickle.load(f)

# %%
#data

# %%
full_text = []

with open(filename2, "rb") as file:
    while True:
        try:
            tweet = pickle.load(file)
            #full_text.append(tweet['full_text'])
            full_text.append(tweet)
            #print(tweet.keys())
        except EOFError:
            break

# %%
len(full_text)
# Out:
# 76868

# %%
type(full_text)
# Out:
# list

# %%
with open("sample.json", "w") as outfile: 
    json.dump(full_text, outfile)

# %%
df_biden = pd.DataFrame(full_text)

# %%
df_biden
# Out:
#                            created_at                   id  \
# 0      Thu Oct 22 23:59:59 +0000 2020  1319428320233140224
# 1      Thu Oct 22 23:59:59 +0000 2020  1319428320140926978
# 2      Thu Oct 22 23:59:59 +0000 2020  1319428320077901824
# 3      Thu Oct 22 23:59:59 +0000 2020  1319428319809593346
# 4      Thu Oct 22 23:59:59 +0000 2020  1319428319587102720
# ...                               ...                  ...
# 76863  Mon Dec 14 23:56:27 +0000 2020  1338633986310955009
# 76864  Mon Dec 14 23:56:27 +0000 2020  1338633986197819394
# 76865  Mon Dec 14 23:56:27 +0000 2020  1338633986185322497
# 76866  Mon Dec 14 23:56:27 +0000 2020  1338633986097164288
# 76867  Mon Dec 14 23:56:27 +0000 2020  1338633986067795970
#
#                     id_str                                          full_text  \
# 0      1319428320233140224  RT @bennyjohnson: 🚨 BOMBSHELL🚨 \n\nVeteran &am...
# 1      1319428320140926978  RT @realDonaldTrump: Finally! Suburban women a...
# 2      1319428320077901824  RT @MaajidNawaz: BREAKING:\nUS Navy veteran Lt...
# 3      1319428319809593346  RT @JonahDispatch: Lara Trump has said three t...
# 4      1319428319587102720  RT @cenkuygur: Why is no journalist asking why...
# ...                    ...                                                ...
# 76863  1338633986310955009  RT @funder: California (55) affirms Biden’s wi...
# 76864  1338633986197819394  RT @voxdotcom: Trump's “alternate slate of ele...
# 76865  1338633986185322497  @JoeBiden @DrBiden @KamalaHarris @DouglasEmhof...
# 76866  1338633986097164288  President- elect Joe Biden. It feels good and ...
# 76867  1338633986067795970  RT @Amy_Siskind: Barr must be held accountable...
#
#        truncated display_text_range  \
# 0          False           [0, 147]
# 1          False           [0, 140]
# 2          False           [0, 140]
# 3          False           [0, 139]
# 4          False           [0, 140]
# ...          ...                ...
# 76863      False            [0, 89]
# 76864      False           [0, 140]
# 76865      False           [0, 276]
# 76866      False            [0, 52]
# 76867      False           [0, 140]
#
#                                                 entities  \
# 0      {'hashtags': [], 'symbols': [], 'user_mentions...
# 1      {'hashtags': [], 'symbols': [], 'user_mentions...
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...
# 3      {'hashtags': [], 'symbols': [], 'user_mentions...
# 4      {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                                                  ...
# 76863  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76864  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76865  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76866  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76867  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 76863  {'iso_language_code': 'en', 'result_type': 're...
# 76864  {'iso_language_code': 'en', 'result_type': 're...
# 76865  {'iso_language_code': 'en', 'result_type': 're...
# 76866  {'iso_language_code': 'en', 'result_type': 're...
# 76867  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="https://mobile.twitter.com" rel="nofo...
# 2      <a href="http://twitter.com/download/android" ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...
# 4      <a href="http://twitter.com/download/android" ...
# ...                                                  ...
# 76863  <a href="http://twitter.com/download/iphone" r...
# 76864  <a href="https://about.twitter.com/products/tw...
# 76865  <a href="http://twitter.com/download/iphone" r...
# 76866  <a href="https://mobile.twitter.com" rel="nofo...
# 76867  <a href="https://mobile.twitter.com" rel="nofo...
#
#        in_reply_to_status_id  ... favorite_count  favorited retweeted lang  \
# 0                        NaN  ...              0      False     False   en
# 1                        NaN  ...              0      False     False   en
# 2                        NaN  ...              0      False     False   en
# 3                        NaN  ...              0      False     False   en
# 4                        NaN  ...              0      False     False   en
# ...                      ...  ...            ...        ...       ...  ...
# 76863                    NaN  ...              0      False     False   en
# 76864                    NaN  ...              0      False     False   en
# 76865                    NaN  ...              0      False     False   en
# 76866                    NaN  ...              5      False     False   en
# 76867                    NaN  ...              0      False     False   en
#
#       possibly_sensitive quoted_status_id quoted_status_id_str  \
# 0                    NaN              NaN                  NaN
# 1                    NaN              NaN                  NaN
# 2                  False              NaN                  NaN
# 3                    NaN              NaN                  NaN
# 4                    NaN              NaN                  NaN
# ...                  ...              ...                  ...
# 76863                NaN              NaN                  NaN
# 76864                NaN              NaN                  NaN
# 76865                NaN              NaN                  NaN
# 76866              False     1.338612e+18  1338612046896771072
# 76867                NaN     1.338629e+18  1338629349738770446
#
#                                            quoted_status extended_entities  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 76863                                                NaN               NaN
# 76864                                                NaN               NaN
# 76865                                                NaN               NaN
# 76866  {'created_at': 'Mon Dec 14 22:29:16 +0000 2020...               NaN
# 76867                                                NaN               NaN
#
#       withheld_in_countries
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 76863                   NaN
# 76864                   NaN
# 76865                   NaN
# 76866                   NaN
# 76867                   NaN
#
# [76868 rows x 32 columns]

# %%
#Converting the list to a data frame for further analysis

# %%
trump_df = pd.DataFrame (full_text,columns=['tweet'])

# %%
trump_df
# Out:
#                                                     tweet
# 0       RT @ThomboyD: Ok, how many warnings does trump...
# 1       RT @JonahDispatch: Lara Trump has said three t...
# 2       RT @jburnmurdoch: I particularly love this won...
# 3       RT @AliVelshi: BREAKING: A federal judge in NJ...
# 4       RT @RepsForBiden: Let’s make sure Trump is bei...
# ...                                                   ...
# 118225  RT @mkraju: Trump’s Hill allies blindsided by ...
# 118226  RT @CNNPolitics: JUST IN: The Electoral Colleg...
# 118227  RT @CNBCnow: BREAKING: President-elect Joe Bid...
# 118228  @RomanSaluter @TitusNation The crowd is cheeri...
# 118229  RT @RepAdamSchiff: Attorney General Bill Barr:...
#
# [118230 rows x 1 columns]

# %%
nltk.download('words')
words = set(nltk.corpus.words.words())
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/alexkowalski/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def cleaner(tweet):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet) \
         if w.lower() in words or not w.isalpha())
    return tweet

# %%
df_biden['full_text'] = df_biden['full_text'].map(lambda x: cleaner(x))

# %%
df_biden
# Out:
#                            created_at                   id  \
# 0      Thu Oct 22 23:59:59 +0000 2020  1319428320233140224
# 1      Thu Oct 22 23:59:59 +0000 2020  1319428320140926978
# 2      Thu Oct 22 23:59:59 +0000 2020  1319428320077901824
# 3      Thu Oct 22 23:59:59 +0000 2020  1319428319809593346
# 4      Thu Oct 22 23:59:59 +0000 2020  1319428319587102720
# ...                               ...                  ...
# 76863  Mon Dec 14 23:56:27 +0000 2020  1338633986310955009
# 76864  Mon Dec 14 23:56:27 +0000 2020  1338633986197819394
# 76865  Mon Dec 14 23:56:27 +0000 2020  1338633986185322497
# 76866  Mon Dec 14 23:56:27 +0000 2020  1338633986097164288
# 76867  Mon Dec 14 23:56:27 +0000 2020  1338633986067795970
#
#                     id_str                                          full_text  \
# 0      1319428320233140224  : 🚨 BOMBSHELL 🚨 Veteran & ; business partner o...
# 1      1319428320140926978  : Finally ! Suburban are flocking over to us ....
# 2      1319428320077901824  : BREAKING : US Navy veteran Tony ,, ’ s forme...
# 3      1319428319809593346  : Trump said three times during an interview o...
# 4      1319428319587102720  : Why is no journalist why team ' t used at al...
# ...                    ...                                                ...
# 76863  1338633986310955009  : ( 55 ) ’ s win . ’ s total is now 302 . It ’...
# 76864  1338633986197819394  : Trump ' s “ alternate slate of ” have no leg...
# 76865  1338633986185322497  PRESIDENT AND MADAM VICE PRESIDENT , , and esp...
# 76866  1338633986097164288        President - elect Joe . It good and right .
# 76867  1338633986067795970  : must be accountable - and the administration...
#
#        truncated display_text_range  \
# 0          False           [0, 147]
# 1          False           [0, 140]
# 2          False           [0, 140]
# 3          False           [0, 139]
# 4          False           [0, 140]
# ...          ...                ...
# 76863      False            [0, 89]
# 76864      False           [0, 140]
# 76865      False           [0, 276]
# 76866      False            [0, 52]
# 76867      False           [0, 140]
#
#                                                 entities  \
# 0      {'hashtags': [], 'symbols': [], 'user_mentions...
# 1      {'hashtags': [], 'symbols': [], 'user_mentions...
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...
# 3      {'hashtags': [], 'symbols': [], 'user_mentions...
# 4      {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                                                  ...
# 76863  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76864  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76865  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76866  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76867  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 76863  {'iso_language_code': 'en', 'result_type': 're...
# 76864  {'iso_language_code': 'en', 'result_type': 're...
# 76865  {'iso_language_code': 'en', 'result_type': 're...
# 76866  {'iso_language_code': 'en', 'result_type': 're...
# 76867  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="https://mobile.twitter.com" rel="nofo...
# 2      <a href="http://twitter.com/download/android" ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...
# 4      <a href="http://twitter.com/download/android" ...
# ...                                                  ...
# 76863  <a href="http://twitter.com/download/iphone" r...
# 76864  <a href="https://about.twitter.com/products/tw...
# 76865  <a href="http://twitter.com/download/iphone" r...
# 76866  <a href="https://mobile.twitter.com" rel="nofo...
# 76867  <a href="https://mobile.twitter.com" rel="nofo...
#
#        in_reply_to_status_id  ... favorite_count  favorited retweeted lang  \
# 0                        NaN  ...              0      False     False   en
# 1                        NaN  ...              0      False     False   en
# 2                        NaN  ...              0      False     False   en
# 3                        NaN  ...              0      False     False   en
# 4                        NaN  ...              0      False     False   en
# ...                      ...  ...            ...        ...       ...  ...
# 76863                    NaN  ...              0      False     False   en
# 76864                    NaN  ...              0      False     False   en
# 76865                    NaN  ...              0      False     False   en
# 76866                    NaN  ...              5      False     False   en
# 76867                    NaN  ...              0      False     False   en
#
#       possibly_sensitive quoted_status_id quoted_status_id_str  \
# 0                    NaN              NaN                  NaN
# 1                    NaN              NaN                  NaN
# 2                  False              NaN                  NaN
# 3                    NaN              NaN                  NaN
# 4                    NaN              NaN                  NaN
# ...                  ...              ...                  ...
# 76863                NaN              NaN                  NaN
# 76864                NaN              NaN                  NaN
# 76865                NaN              NaN                  NaN
# 76866              False     1.338612e+18  1338612046896771072
# 76867                NaN     1.338629e+18  1338629349738770446
#
#                                            quoted_status extended_entities  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 76863                                                NaN               NaN
# 76864                                                NaN               NaN
# 76865                                                NaN               NaN
# 76866  {'created_at': 'Mon Dec 14 22:29:16 +0000 2020...               NaN
# 76867                                                NaN               NaN
#
#       withheld_in_countries
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 76863                   NaN
# 76864                   NaN
# 76865                   NaN
# 76866                   NaN
# 76867                   NaN
#
# [76868 rows x 32 columns]

# %%
# word cloud for Trump

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

# %%
mpl.rcParams['figure.figsize']=(16.0,10.0)    
mpl.rcParams['font.size']=12                
mpl.rcParams['savefig.dpi']=1400             
mpl.rcParams['figure.subplot.bottom']=.1 

stopwords = set(STOPWORDS)
text = " ".join(tweet for tweet in trump_df.tweet)
print ("There are {} words in the combination of all tweets.".format(len(text)))

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(text))
# Out:
# There are 11682719 words in the combination of all tweets.

# %%
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=1400)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fcc8921fa50>

# %%
# Most popular words for Trump

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Helper function
def plot_20_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:20]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    plt.figure(figsize=(16, 10))
    plt.bar(x_pos, counts,align='center')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.title('20 most common words')
    plt.show()

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(trump_df['tweet'])

# Visualise the 20 most common words
plot_20_most_common_words(count_data, count_vectorizer)

# %%
from IPython.display import Javascript
from datetime import datetime

# %%
compression_opts = dict(method='zip', archive_name='biden_cleaned.csv')

# %%
df_biden.to_csv('biden_cleaned.zip', index=False, compression=compression_opts)

# %%
df_biden
# Out:
#                            created_at                   id  \
# 0      Thu Oct 22 23:59:59 +0000 2020  1319428320233140224
# 1      Thu Oct 22 23:59:59 +0000 2020  1319428320140926978
# 2      Thu Oct 22 23:59:59 +0000 2020  1319428320077901824
# 3      Thu Oct 22 23:59:59 +0000 2020  1319428319809593346
# 4      Thu Oct 22 23:59:59 +0000 2020  1319428319587102720
# ...                               ...                  ...
# 76863  Mon Dec 14 23:56:27 +0000 2020  1338633986310955009
# 76864  Mon Dec 14 23:56:27 +0000 2020  1338633986197819394
# 76865  Mon Dec 14 23:56:27 +0000 2020  1338633986185322497
# 76866  Mon Dec 14 23:56:27 +0000 2020  1338633986097164288
# 76867  Mon Dec 14 23:56:27 +0000 2020  1338633986067795970
#
#                     id_str                                          full_text  \
# 0      1319428320233140224  : 🚨 BOMBSHELL 🚨 Veteran & ; business partner o...
# 1      1319428320140926978  : Finally ! Suburban are flocking over to us ....
# 2      1319428320077901824  : BREAKING : US Navy veteran Tony ,, ’ s forme...
# 3      1319428319809593346  : Trump said three times during an interview o...
# 4      1319428319587102720  : Why is no journalist why team ' t used at al...
# ...                    ...                                                ...
# 76863  1338633986310955009  : ( 55 ) ’ s win . ’ s total is now 302 . It ’...
# 76864  1338633986197819394  : Trump ' s “ alternate slate of ” have no leg...
# 76865  1338633986185322497  PRESIDENT AND MADAM VICE PRESIDENT , , and esp...
# 76866  1338633986097164288        President - elect Joe . It good and right .
# 76867  1338633986067795970  : must be accountable - and the administration...
#
#        truncated display_text_range  \
# 0          False           [0, 147]
# 1          False           [0, 140]
# 2          False           [0, 140]
# 3          False           [0, 139]
# 4          False           [0, 140]
# ...          ...                ...
# 76863      False            [0, 89]
# 76864      False           [0, 140]
# 76865      False           [0, 276]
# 76866      False            [0, 52]
# 76867      False           [0, 140]
#
#                                                 entities  \
# 0      {'hashtags': [], 'symbols': [], 'user_mentions...
# 1      {'hashtags': [], 'symbols': [], 'user_mentions...
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...
# 3      {'hashtags': [], 'symbols': [], 'user_mentions...
# 4      {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                                                  ...
# 76863  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76864  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76865  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76866  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76867  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 76863  {'iso_language_code': 'en', 'result_type': 're...
# 76864  {'iso_language_code': 'en', 'result_type': 're...
# 76865  {'iso_language_code': 'en', 'result_type': 're...
# 76866  {'iso_language_code': 'en', 'result_type': 're...
# 76867  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="https://mobile.twitter.com" rel="nofo...
# 2      <a href="http://twitter.com/download/android" ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...
# 4      <a href="http://twitter.com/download/android" ...
# ...                                                  ...
# 76863  <a href="http://twitter.com/download/iphone" r...
# 76864  <a href="https://about.twitter.com/products/tw...
# 76865  <a href="http://twitter.com/download/iphone" r...
# 76866  <a href="https://mobile.twitter.com" rel="nofo...
# 76867  <a href="https://mobile.twitter.com" rel="nofo...
#
#        in_reply_to_status_id  ... favorite_count  favorited retweeted lang  \
# 0                        NaN  ...              0      False     False   en
# 1                        NaN  ...              0      False     False   en
# 2                        NaN  ...              0      False     False   en
# 3                        NaN  ...              0      False     False   en
# 4                        NaN  ...              0      False     False   en
# ...                      ...  ...            ...        ...       ...  ...
# 76863                    NaN  ...              0      False     False   en
# 76864                    NaN  ...              0      False     False   en
# 76865                    NaN  ...              0      False     False   en
# 76866                    NaN  ...              5      False     False   en
# 76867                    NaN  ...              0      False     False   en
#
#       possibly_sensitive quoted_status_id quoted_status_id_str  \
# 0                    NaN              NaN                  NaN
# 1                    NaN              NaN                  NaN
# 2                  False              NaN                  NaN
# 3                    NaN              NaN                  NaN
# 4                    NaN              NaN                  NaN
# ...                  ...              ...                  ...
# 76863                NaN              NaN                  NaN
# 76864                NaN              NaN                  NaN
# 76865                NaN              NaN                  NaN
# 76866              False     1.338612e+18  1338612046896771072
# 76867                NaN     1.338629e+18  1338629349738770446
#
#                                            quoted_status extended_entities  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 76863                                                NaN               NaN
# 76864                                                NaN               NaN
# 76865                                                NaN               NaN
# 76866  {'created_at': 'Mon Dec 14 22:29:16 +0000 2020...               NaN
# 76867                                                NaN               NaN
#
#       withheld_in_countries
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 76863                   NaN
# 76864                   NaN
# 76865                   NaN
# 76866                   NaN
# 76867                   NaN
#
# [76868 rows x 32 columns]

# %%
df_biden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76868 entries, 0 to 76867
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 76868 non-null  object
#  1   id                         76868 non-null  int64
#  2   id_str                     76868 non-null  object
#  3   full_text                  76868 non-null  object
#  4   truncated                  76868 non-null  bool
#  5   display_text_range         76868 non-null  object
#  6   entities                   76868 non-null  object
#  7   metadata                   76868 non-null  object
#  8   source                     76868 non-null  object
#  9   in_reply_to_status_id      11542 non-null  float64
#  10  in_reply_to_status_id_str  11542 non-null  object
#  11  in_reply_to_user_id        12024 non-null  float64
#  12  in_reply_to_user_id_str    12024 non-null  object
#  13  in_reply_to_screen_name    12024 non-null  object
#  14  user                       76868 non-null  object
#  15  geo                        2 non-null      object
#  16  coordinates                2 non-null      object
#  17  place                      408 non-null    object
#  18  contributors               0 non-null      object
#  19  retweeted_status           57167 non-null  object
#  20  is_quote_status            76868 non-null  bool
#  21  retweet_count              76868 non-null  int64
#  22  favorite_count             76868 non-null  int64
#  23  favorited                  76868 non-null  bool
#  24  retweeted                  76868 non-null  bool
#  25  lang                       76868 non-null  object
#  26  possibly_sensitive         13270 non-null  object
#  27  quoted_status_id           5448 non-null   float64
#  28  quoted_status_id_str       5448 non-null   object
#  29  quoted_status              1633 non-null   object
#  30  extended_entities          3693 non-null   object
#  31  withheld_in_countries      8 non-null      object
# dtypes: bool(4), float64(3), int64(3), object(22)
# memory usage: 16.7+ MB

# %%
fav_max = np.max(bg['favorite_count'])
rt_max  = np.max(bg['retweet_count'])

fav = bg[bg.favorite_count == fav_max].index[0]
rt  = bg[bg.retweet_count == rt_max].index[0]

# Max FAVs:
print("The tweet with more likes is: \n{}".format(bg['tweet'][fav]))
print("Number of likes: {}".format(fav_max))

# Max RTs:
print("The tweet with more retweets is: \n{}".format(bg['tweet'][rt]))
print("Number of retweets: {}".format(rt_max))
